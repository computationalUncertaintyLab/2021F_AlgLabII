# %% [markdown]
# # Applied Regression
#
# For this assignment we will be investigating the NHANES dataset, a huge repository of survey data about health outcomes and bevhaiors.
#
# https://cran.r-project.org/web/packages/NHANES/NHANES.pdf

# %% [markdown]
# ## Q1 Install the NHANES package

# %%
install.packages("NHANES")
# Out:
# Installing package into ‘/opt/homebrew/lib/R/4.1/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ## Read in the dataset

# %%
library(NHANES)


# effect of age on pregnancy
#NHANES$PhysActiveDays_numeric <- as.numeric(NHANES$PhysActiveDays)

NHANES$CompHrsDay_Numeric <- as.numeric(NHANES$CompHrsDay)
plot(NHANES$CompHrsDay_Numeric ,NHANES$PhysActiveDays_numeric)

fit <- lm(PhysActiveDays_numeric ~CompHrsDay_Numeric ,data=NHANES)
summary(fit)

hist(rnorm(1000,0.003176,0.023103))
# Out:
# Call:
# lm(formula = PhysActiveDays_numeric ~ CompHrsDay_Numeric, data = NHANES)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8363 -1.8173  0.1669  1.1796  3.1827
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        3.814082   0.075416  50.574   <2e-16 ***
# CompHrsDay_Numeric 0.003176   0.023103   0.137    0.891
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.837 on 2309 degrees of freedom
#   (7689 observations deleted due to missingness)
# Multiple R-squared:  8.184e-06,	Adjusted R-squared:  -0.0004249
# F-statistic: 0.0189 on 1 and 2309 DF,  p-value: 0.8907
# plot without title
# Plot with title “Histogram of rnorm(1000, 0.003176, 0.023103)”

# %% [markdown]
# ## Q1 How many columns does NHANES have?

# %% [markdown]
# ## Q2 Plot a histogram of the BMI variable from the NHANES data set. How many patients do we have?

# %% [markdown]
# ## Q3 What is the average, max and min of the BMI variable?

# %% [markdown]
# ## Q4 Is poverty related to BMI?

# %% [markdown]
# ## Q5 Is poverty related to BMI controlling for age?

# %% [markdown]
# ## Q6 Is poverty related to education?
