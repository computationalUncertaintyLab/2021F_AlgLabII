# %% [markdown]
# # Multivariate Regression Interpretation

# %% [markdown]
# $$ y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \epsilon$$
# $$ \epsilon \sim N(0,\sigma^2)$$

# %% [markdown]
# We know how to interpret $\beta_1$ in a univariate regression. It is the effect of a unit change of x on y. In multivariate regression we can no longer say this.
#
# We now say that $\beta_1$ is the effect of $x_1$ on $y$ at all levels of $x_2$. No matter what value we plug into $x_2$ we see the same effect on $y$ of $x_1$.

# %% [markdown]
# # Checkpoint
#
# Suppose we have the regression,
#
# $$y = 2 + 3x_1 + 4x_2 + \epsilon$$
#
# What happens to $y$ when we increase $x_1$ by 1 unit when $x_2$ = 0?
#
# What happens to $y$ when we increase $x_1$ by 1 unit when $x_2$ = 1?
#
#
#
# $$y = 2 + 3(x_1+1) + 4 + \epsilon$$
# $$y = 2 + 3x_1+ 3 + 4 + \epsilon$$

# %% [markdown]
# $$Cancer = 3 + 2*Alcohol +  3*Smoking$$

# %% [markdown]
# # NHANES Multivariate
#
# Let's take a look at a real data example using NHANES.

# %%
library("NHANES")

summary(NHANES$SmokeNow)
#hist(NHANES$AlcoholDay)

plot(NHANES$SmokeNow,NHANES$BPDiaAve)
plot(NHANES$AlcoholDay,NHANES$BPDiaAve)

#hist(NHANES$BPDiaAve)

fit <- lm( BPDiaAve ~  AlcoholDay +SmokeNow ,NHANES)
summary(fit)
# Out:
#   No  Yes NA's
# 1745 1466 6789
# plot without title
# Call:
# lm(formula = BPDiaAve ~ AlcoholDay + SmokeNow, data = NHANES)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -70.707  -7.111   0.451   7.526  45.322
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 70.50280    0.40377 174.612  < 2e-16 ***
# AlcoholDay   0.20460    0.07834   2.612  0.00907 **
# SmokeNowYes -0.84742    0.53577  -1.582  0.11386
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.27 on 2251 degrees of freedom
#   (7746 observations deleted due to missingness)
# Multiple R-squared:  0.003428,	Adjusted R-squared:  0.002542
# F-statistic: 3.871 on 2 and 2251 DF,  p-value: 0.02097
# plot without title

# %% [markdown]
# We can interpret $\beta_1$ as the effect of drinking on blood pressure for all levels of smoking (yes/no).

# %%
plot(fit)
hist(residuals(fit))
NHANES[5252,]
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
#      ID    SurveyYr Gender Age AgeDecade AgeMonths Race1 Race3 Education
# 5252 62632 2011_12  male   29   20-29    NA        Other Asian 9 - 11th Grade
#      MaritalStatus ⋯ RegularMarij AgeRegMarij HardDrugs SexEver SexAge
# 5252 NeverMarried  ⋯ Yes          15          No        Yes     17
#      SexNumPartnLife SexNumPartYear SameSex SexOrientation PregnantNow
# 5252 25              1              No      Heterosexual   NA
# Plot with title “Histogram of residuals(fit)”

# %%
NHANES_WITHOUT_62632 <- NHANES[NHANES$ID != 62632,]

# %%
fit <- lm( BPDiaAve ~  AlcoholDay +SmokeNow ,NHANES)
summary(fit)
plot(fit)
# Out:
# Call:
# lm(formula = BPDiaAve ~ AlcoholDay + SmokeNow, data = NHANES)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -70.707  -7.111   0.451   7.526  45.322
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 70.50280    0.40377 174.612  < 2e-16 ***
# AlcoholDay   0.20460    0.07834   2.612  0.00907 **
# SmokeNowYes -0.84742    0.53577  -1.582  0.11386
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.27 on 2251 degrees of freedom
#   (7746 observations deleted due to missingness)
# Multiple R-squared:  0.003428,	Adjusted R-squared:  0.002542
# F-statistic: 3.871 on 2 and 2251 DF,  p-value: 0.02097
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
